
#     Complete output (2 lines):
#     Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/d1/fcdb32513a03abfde0d97fd9782ce0f8cc0540fa6c6ce783e87b94064964/Fiona-1.8.3.tar.gz#sha256=3e831100a23c3b6cd32b98baf0c9e2119d909b44a5cf4533d3625f61dcf2d2b1 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/moidshaikh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_bc22d04936f14695ab0e470ee888cc1e/setup.py'"'"'; __file__='"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_bc22d04936f14695ab0e470ee888cc1e/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-pip-egg-info-dveld4q8
#          cwd: /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_bc22d04936f14695ab0e470ee888cc1e/
#     Complete output (2 lines):
#     Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/25/50/0466d5d83e1859c5ca38351ee932d64cc5635f9d4dad522879e58f4b0018/Fiona-1.8.2.tar.gz#sha256=4c6419b7ac29136708029f6a44b4ccd458735a4d241016c7b1bab41685c08d8f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/moidshaikh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_612c8a339d2d4a56bd3deed6baa79b66/setup.py'"'"'; __file__='"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_612c8a339d2d4a56bd3deed6baa79b66/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-pip-egg-info-ag6tdwk2
#          cwd: /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_612c8a339d2d4a56bd3deed6baa79b66/
#     Complete output (2 lines):
#     Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/5f/0c6704efeea2ff3fba7f54cc6ec38070157f21bc1cffa7bdfa7c9f6b8f7a/Fiona-1.8.1.tar.gz#sha256=4c34bb4c5cd788aaf14e5484c3b7de407b1a8a7c7b2d29bbb2e8b37931e83b8d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/moidshaikh/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_f60b14f176914dd5af185e886377655a/setup.py'"'"'; __file__='"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_f60b14f176914dd5af185e886377655a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-pip-egg-info-wwto3itr
#          cwd: /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_f60b14f176914dd5af185e886377655a/
#     Complete output (2 lines):
#     Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/bd/c1efc2680f338e5941121c776d6323af6b9698ac739e22ba523cee348a7f/Fiona-1.8.0.tar.gz#sha256=20141a9ece06daa7bb4333fba640c2fe39a49f8aca5492d1da8595d41e91844a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting geopandas
#   Using cached geopandas-0.12.1-py3-none-any.whl (1.1 MB)
#   Using cached geopandas-0.12.0-py3-none-any.whl (1.1 MB)
# Collecting shapely<2,>=1.7
#   Using cached Shapely-1.8.5.post1-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
# Collecting geopandas
#   Using cached geopandas-0.11.1-py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.11.0-py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pandas>=0.25.0 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (1.21.5)
# Requirement already satisfied: certifi in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from pyproj>=2.6.1.post1->geopandas) (2022.5.18.1)
# Requirement already satisfied: six>=1.5 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.25.0->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.4 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages (from cligj>=0.4->fiona->geopandas) (8.0.4)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/moidshaikh/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/setup.py'"'"'; __file__='"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-wheel-1shvvfg3
#        cwd: /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/
#   Complete output (50 lines):
#   Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#   /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-11.1-arm64-3.9
#   creating build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/compat.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/drvsupport.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/inspector.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/__init__.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/crs.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/rfc3339.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/transform.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/collection.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/errors.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   copying ./fiona/tool.py -> build/lib.macosx-11.1-arm64-3.9/fiona
#   creating build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/options.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/collect.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/distrib.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/env.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/insp.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/cat.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/__init__.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/ls.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/dump.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/calc.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/filter.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/load.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/main.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/info.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/helpers.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   copying ./fiona/fio/bounds.py -> build/lib.macosx-11.1-arm64-3.9/fiona/fio
#   running build_ext
#   building 'fiona._transform' extension
#   creating build/temp.macosx-11.1-arm64-3.9
#   creating build/temp.macosx-11.1-arm64-3.9/fiona
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/moidshaikh/opt/anaconda3/include -arch arm64 -I/Users/moidshaikh/opt/anaconda3/include -fPIC -O2 -isystem /Users/moidshaikh/opt/anaconda3/include -arch arm64 -I/Users/moidshaikh/opt/anaconda3/include/python3.9 -c fiona/_transform.cpp -o build/temp.macosx-11.1-arm64-3.9/fiona/_transform.o
#   fiona/_transform.cpp:606:10: fatal error: 'cpl_conv.h' file not found
#   #include "cpl_conv.h"
#            ^~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: shapely, pyproj, fiona, geopandas
#     Running setup.py install for fiona ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/moidshaikh/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/setup.py'"'"'; __file__='"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-record-xqu_6wh1/install-record.txt --single-version-externally-managed --compile --install-headers /Users/moidshaikh/opt/anaconda3/include/python3.9/fiona
#          cwd: /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/
#     Complete output (22 lines):
#     Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#     /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/dist.py:275: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     /Users/moidshaikh/opt/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     creating build/temp.macosx-11.1-arm64-3.9
#     creating build/temp.macosx-11.1-arm64-3.9/fiona
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/moidshaikh/opt/anaconda3/include -arch arm64 -I/Users/moidshaikh/opt/anaconda3/include -fPIC -O2 -isystem /Users/moidshaikh/opt/anaconda3/include -arch arm64 -I/Users/moidshaikh/opt/anaconda3/include/python3.9 -c fiona/_transform.cpp -o build/temp.macosx-11.1-arm64-3.9/fiona/_transform.o
#     fiona/_transform.cpp:606:10: fatal error: 'cpl_conv.h' file not found
#     #include "cpl_conv.h"
#              ^~~~~~~~~~~~
#     1 error generated.
#     error: command '/usr/bin/clang' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/moidshaikh/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/setup.py'"'"'; __file__='"'"'/private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-install-ti6sc686/fiona_83db7fd737c94592aaf587321b10cdf8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/df/8_qds2ns5t50hs447k_yybv80000gn/T/pip-record-xqu_6wh1/install-record.txt --single-version-externally-managed --compile --install-headers /Users/moidshaikh/opt/anaconda3/include/python3.9/fiona Check the logs for full command output.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 get_ipython().system('pip install geopandas')
# ----> 2 import geopandas as gpd
#       3 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       4 world.plot()
#
# ModuleNotFoundError: No module named 'geopandas'
